# %%
import os
import sys
import numpy as np
import librosa
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
import tensorflow.keras
import tensorflow.keras.layers as layers
import IPython.display as ipd
from tensorflow.keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt




print("Python version:", sys.version)
print("NumPy version:", np.__version__)
print("librosa version:", librosa.__version__)
print("TensorFlow version:", tf.__version__)
# Out:
# Python version: 3.8.20 (default, Oct  3 2024, 15:19:54) [MSC v.1929 64 bit (AMD64)]
# NumPy version: 1.19.5
# librosa version: 0.9.2
# TensorFlow version: 2.5.3

# %%
def preprocess_file(song_path, n_mfcc=128, num_segments=14):
    """
    Preprocess a single song into MFCC feature segments.
    Each segment is reshaped to (16, 8, 1).
    """
    mfcc_segments = []

    try:
        duration = librosa.get_duration(filename=song_path)

        if duration > 90:
            audio, sr = librosa.load(
                song_path,
                sr=None,
                offset=30,
                duration=60
            )
        else:
            audio, sr = librosa.load(song_path, sr=None)

        total_samples = len(audio)
        segment_length = total_samples // num_segments

        for s in range(num_segments):
            start = s * segment_length
            end = start + segment_length
            segment = audio[start:end]

            if len(segment) < segment_length // 2:
                continue

            mfcc = librosa.feature.mfcc(y=segment, sr=sr, n_mfcc=n_mfcc)
            mfcc_mean = np.mean(mfcc.T, axis=0)
            mfcc_reshaped = np.reshape(mfcc_mean, (16, 8, 1))
            mfcc_segments.append(mfcc_reshaped)

    except Exception as e:
        print(f"Error processing {song_path}: {e}")

    return mfcc_segments


def preprocess_dataset(parent_dir, genres, n_mfcc=128, num_segments=14, max_files=None):
    dataset = []
    labels = []

    for genre, genre_number in genres.items():
        genre_dir = os.path.join(parent_dir, genre)
        print(f"Processing genre: {genre}")

        files = [f for f in os.listdir(genre_dir) if f.endswith((".wav", ".au", ".mp3"))]
        if max_files:
            files = files[:max_files]

        for filename in files:
            song_path = os.path.join(genre_dir, filename)
            mfcc_segments = preprocess_file(song_path, n_mfcc, num_segments)

            dataset.extend(mfcc_segments)
            labels.extend([genre_number] * len(mfcc_segments))

    dataset = np.array(dataset)
    labels = np.array(labels)

    print("Final dataset shape:", dataset.shape)
    print("Final labels shape:", labels.shape)
    return dataset, labels

# %%
Xcheck= preprocess_file("data/genresMP3/classical/classical.00003.mp3")
print(np.array(Xcheck).shape)
# Out:
# (14, 16, 8, 1)

# %%
genres = {
    'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4,
    'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9
}

X, y = preprocess_dataset("data/genresMP3", genres)
# Out:
# Processing genre: blues
# Processing genre: classical
# Processing genre: country
# Processing genre: disco
# Processing genre: hiphop
# Processing genre: jazz
# Processing genre: metal
# Processing genre: pop
# Processing genre: reggae
# Processing genre: rock
# Final dataset shape: (14000, 16, 8, 1)
# Final labels shape: (14000,)

# %%
y.shape
# Out:
# (14000, 10)

# %%
X.shape
# Out:
# (14000, 16, 8, 1)

# %%
labelencoder = LabelEncoder()
y = to_categorical(labelencoder.fit_transform(y))


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
INPUTSHAPE = (16,8,1)
model = Sequential([

    layers.Conv2D(32 , (3,3),activation = 'relu',padding='valid', input_shape = INPUTSHAPE),
    layers.MaxPooling2D(2, padding='same'),
    layers.Flatten(),
    layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.Dense(10 , activation = 'softmax')
])

model.compile(loss = 'categorical_crossentropy', optimizer
= 'adam'
, metrics =['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 14, 6, 32)         320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 3, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 672)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               344576
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 350,026
# Trainable params: 350,026
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=8, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=1)
#checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5',
                             # verbose=1, save_best_only=True)
history = model.fit(X_train,y_train ,validation_data=(X_test,y_test),
            epochs=50,
            verbose=1,
            callbacks = [lr_scheduler],batch_size=batch_size)
# Out:
# Epoch 1/50
# 77/77 [==============================] - 2s 15ms/step - loss: 2.0766 - accuracy: 0.4222 - val_loss: 1.3818 - val_accuracy: 0.5498
# Epoch 2/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.3131 - accuracy: 0.5733 - val_loss: 1.2012 - val_accuracy: 0.6162
# Epoch 3/50
# 77/77 [==============================] - 1s 11ms/step - loss: 1.1722 - accuracy: 0.6155 - val_loss: 1.2485 - val_accuracy: 0.5993
# Epoch 4/50
# 77/77 [==============================] - 1s 11ms/step - loss: 0.9735 - accuracy: 0.6962 - val_loss: 1.0130 - val_accuracy: 0.6833
# Epoch 5/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.9173 - accuracy: 0.7149 - val_loss: 0.9602 - val_accuracy: 0.7021
# Epoch 6/50
# 77/77 [==============================] - 1s 11ms/step - loss: 0.8622 - accuracy: 0.7362 - val_loss: 0.9426 - val_accuracy: 0.7050
# Epoch 7/50
# 77/77 [==============================] - 1s 11ms/step - loss: 0.8064 - accuracy: 0.7548 - val_loss: 0.9077 - val_accuracy: 0.7219
# Epoch 8/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.7830 - accuracy: 0.7564 - val_loss: 0.9153 - val_accuracy: 0.7126
# Epoch 9/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.6960 - accuracy: 0.7941 - val_loss: 0.8268 - val_accuracy: 0.7483
# Epoch 10/50
# 77/77 [==============================] - 2s 23ms/step - loss: 0.6685 - accuracy: 0.8061 - val_loss: 0.8131 - val_accuracy: 0.7550
# Epoch 11/50
# 77/77 [==============================] - 2s 25ms/step - loss: 0.6510 - accuracy: 0.8090 - val_loss: 0.7937 - val_accuracy: 0.7567
# Epoch 12/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.6289 - accuracy: 0.8207 - val_loss: 0.8440 - val_accuracy: 0.7405
# Epoch 13/50
# 77/77 [==============================] - 2s 20ms/step - loss: 0.5915 - accuracy: 0.8385 - val_loss: 0.7707 - val_accuracy: 0.7679
# Epoch 14/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.5721 - accuracy: 0.8421 - val_loss: 0.7630 - val_accuracy: 0.7721
# Epoch 15/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.5628 - accuracy: 0.8446 - val_loss: 0.7412 - val_accuracy: 0.7786
# Epoch 16/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.5528 - accuracy: 0.8491 - val_loss: 0.7297 - val_accuracy: 0.7774
# Epoch 17/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.5429 - accuracy: 0.8499 - val_loss: 0.7271 - val_accuracy: 0.7743
# Epoch 18/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.5282 - accuracy: 0.8586 - val_loss: 0.7213 - val_accuracy: 0.7838
# Epoch 19/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.5209 - accuracy: 0.8559 - val_loss: 0.7153 - val_accuracy: 0.7788
# Epoch 20/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.5095 - accuracy: 0.8619 - val_loss: 0.7146 - val_accuracy: 0.7798
# Epoch 21/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4949 - accuracy: 0.8677 - val_loss: 0.6928 - val_accuracy: 0.7938
# Epoch 22/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4802 - accuracy: 0.8736 - val_loss: 0.6969 - val_accuracy: 0.7879
# Epoch 23/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4620 - accuracy: 0.8809 - val_loss: 0.6858 - val_accuracy: 0.7929
# Epoch 24/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4600 - accuracy: 0.8817 - val_loss: 0.6792 - val_accuracy: 0.8002
# Epoch 25/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4509 - accuracy: 0.8835 - val_loss: 0.6780 - val_accuracy: 0.7960
# Epoch 26/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4472 - accuracy: 0.8867 - val_loss: 0.6718 - val_accuracy: 0.8000
# Epoch 27/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.4427 - accuracy: 0.8883 - val_loss: 0.6727 - val_accuracy: 0.7986
# Epoch 28/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4308 - accuracy: 0.8918 - val_loss: 0.6602 - val_accuracy: 0.8050
# Epoch 29/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4294 - accuracy: 0.8927 - val_loss: 0.6634 - val_accuracy: 0.8036
# Epoch 30/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4229 - accuracy: 0.8932 - val_loss: 0.6594 - val_accuracy: 0.8040
# Epoch 31/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4214 - accuracy: 0.8964 - val_loss: 0.6595 - val_accuracy: 0.8026
# Epoch 32/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.4189 - accuracy: 0.8964 - val_loss: 0.6575 - val_accuracy: 0.8076
# Epoch 33/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.4176 - accuracy: 0.8980 - val_loss: 0.6566 - val_accuracy: 0.8079
# Epoch 34/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4171 - accuracy: 0.8980 - val_loss: 0.6553 - val_accuracy: 0.8088
# Epoch 35/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4160 - accuracy: 0.8990 - val_loss: 0.6554 - val_accuracy: 0.8067
# Epoch 36/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.4149 - accuracy: 0.8983 - val_loss: 0.6562 - val_accuracy: 0.8064
# Epoch 37/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.4140 - accuracy: 0.8985 - val_loss: 0.6551 - val_accuracy: 0.8076
# Epoch 38/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.4138 - accuracy: 0.8991 - val_loss: 0.6547 - val_accuracy: 0.8076
# Epoch 39/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4136 - accuracy: 0.8986 - val_loss: 0.6544 - val_accuracy: 0.8069
# Epoch 40/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4134 - accuracy: 0.8995 - val_loss: 0.6547 - val_accuracy: 0.8076
# Epoch 41/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4130 - accuracy: 0.8989 - val_loss: 0.6545 - val_accuracy: 0.8071
# Epoch 42/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4128 - accuracy: 0.8993 - val_loss: 0.6544 - val_accuracy: 0.8069
# Epoch 43/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4127 - accuracy: 0.8993 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 44/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 45/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 46/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4126 - accuracy: 0.8990 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 47/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 48/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 49/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074
# Epoch 50/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4126 - accuracy: 0.8991 - val_loss: 0.6544 - val_accuracy: 0.8074

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8604761958122253

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

y_pred_prob = model.predict(X_test, verbose=0)

y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(y_pred_prob, axis=1)
cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)

fig, ax = plt.subplots(figsize=(20, 20))
disp.plot(ax=ax)

plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)


accuracy = accuracy_score(y_true, y_pred)

precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Accuracy : 0.8074
# Precision: 0.8074
# Recall   : 0.8074
# F1 Score : 0.8067

# %%
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay

y_pred=best_model.predict(X_test)
round_off=np.round_(y_pred)
cm=confusion_matrix(y_test.argmax(axis=1),round_off.argmax(axis=1))
print("Confusion Matrix")
print(cm)

plt.figure(figsize=(20,20))
sns.heatmap(cm,annot=True,fmt="d",cmap='Set3')
plt.title("Confusion Matrix")
plt.ylabel("True class")
plt.xlabel("Predicted class")
plt.show()

# %%
##test this
mydict = {
    'Alternative': 0, 'AlternativeHeavy': 1, 'Electronica': 2, 'Metal': 3, 'Punk': 4,
    'Rap': 5, 'Rave': 6, 'Reggae': 7, 'Rock': 8, 'Stoner': 9
}
xtest = np.array(preprocess_file('test/The Mamas & The Papas - California Dreamin.mp3'))
y_pre =model.predict(xtest)
pred_class = np.argmax(y_pre, axis=1)[0]
#print(pred_class)
for genre, classs in mydict.items():
    if classs == pred_class:
        print("Predicted Genre:", genre)

# %%
model.save("THESIS_MFCCTHESIS_MFCC.h5")

# %%
model = tf.keras.models.load_model("THESIS_MFCC.h5")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open("THESIS_MFCCTHESIS_MFCC", "wb") as f:
    f.write(tflite_model)

print("Saved Model successfully.")

# %% [markdown]
# Below Code is based On works of
#
# https://github.com/Manishankar9977/Music-genre-classification/blob/main/music%20gerne%20with%20cnn.ipynb
#
# another PSO trained model is:
#
#       INPUTSHAPE = (16,8,1)
#       model = Sequential([
#
#                                 layers.Conv2D(55 , (3,3),activation = 'relu',padding='valid', input_shape = INPUTSHAPE),
#                                 layers.MaxPooling2D(2, padding='same'),
#                                 layers.Flatten(),
#                                 layers.Dense(313, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
#                                 layers.Dense(10 , activation = 'softmax')
#       ])
#
#       model.compile(loss = 'categorical_crossentropy', optimizer
#       =tf.keras.optimizers.Adam(learning_rate=0.0007842025145903583)
#       #= 'adam'
#       , metrics =['accuracy'])
#       model.summary()
